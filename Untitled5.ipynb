# %% [markdown]
# <a href="https://colab.research.google.com/github/geetika001/DSA-Java-KK-/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
I=Image.open("scenery.jpeg")

# %%
print('Size of Image: ', I.size)
# Out:
# Size of Image:  (300, 168)

# %%
Image.open("scenery.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %% [markdown]
# # **Using Matplotlib**

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('scenery.jpeg')

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# #**Using OpenCV**

# %%
import cv2

# %%
img=cv2.imread("scenery.jpeg")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %% [markdown]
# #**Using scikit-image**

# %%
import skimage.io as io

# %%
image=io.imread('scenery.jpeg')

# %%
io.imshow(image)

# %% [markdown]
# #**Writing and Saving Images**
#
# ###**Use PIL: using save function**

# %%
I=Image.open('scenery.jpeg')

# %%
I1=I.save("Image1.jpeg")

# %%
Image.open("Image1.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %% [markdown]
# ###**Using OpenCV**

# %%
image=cv2.imread("scenery.jpeg")

# %%
filename='savedImage.jpeg'
cv2.imwrite(filename,image[:,:200,:100])
# Out:
# True

# %%
img=cv2.imread('savedImage.jpeg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x168>

# %% [markdown]
# ###**Using scikit-image**

# %%
import skimage.io as io
from skimage.transform import rescale
import numpy as np

# %%
from skimage import io, img_as_ubyte
from skimage.transform import rescale

image = io.imread("scenery.jpeg")

rescaled_image = rescale(image, 0.4)

filename = "savedImage.jpeg"
io.imsave(filename, rescaled_image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-171d2e24542d> in <cell line: 11>()
#       9
#      10 filename = "savedImage.jpeg"
# ---> 11 io.imsave(filename, rescaled_image)
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/_io.py in imsave(fname, arr, plugin, check_contrast, **plugin_args)
#     141     if check_contrast and is_low_contrast(arr):
#     142         warn('%s is a low contrast image' % fname)
# --> 143     return call_plugin('imsave', fname, arr, plugin=plugin, **plugin_args)
#     144
#     145
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.10/dist-packages/imageio/v2.py in imwrite(uri, im, format, **kwargs)
#     395     imopen_args["legacy_mode"] = True
#     396     with imopen(uri, "wi", **imopen_args) as file:
# --> 397         return file.write(im, **kwargs)
#     398
#     399
#
# /usr/local/lib/python3.10/dist-packages/imageio/plugins/pillow.py in write(self, ndimage, mode, format, is_batch, **kwargs)
#     412             is_batch = False
#     413         elif ndimage.ndim == 3 and ndimage.shape[-1] == 1:
# --> 414             raise ValueError("Can't write images with one color channel.")
#     415         elif ndimage.ndim == 3 and ndimage.shape[-1] in [2, 3, 4]:
#     416             # Note: this makes a channel-last assumption
#
# ValueError: Can't write images with one color channel.
